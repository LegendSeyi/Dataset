# %%
import pandas as pd
import requests
from geopy.distance import geodesic

# %%
data = pd.read_csv('AGEGE.csv')

# %%
data
# Out:
#                                title  \
# 0                    Garage Bus Stop
# 1                   Stadium Bus Stop
# 2                 Agunbiade Bus Stop
# 3               Second Gate Bus Stop
# 4                      Pero Bus Stop
# ..                               ...
# 109         Ikeja (General Hospital)
# 110                      LS Bus Stop
# 111                 Balogun Bus Stop
# 112  Grand Manor Hall Omole Bus Stop
# 113           Shobowale street Lagos
#
#                                               placeUrl  category  \
# 0    https://www.google.com/maps/place/Garage+Bus+S...  Bus stop
# 1    https://www.google.com/maps/place/Stadium+Bus+...  Bus stop
# 2    https://www.google.com/maps/place/Agunbiade+Bu...  Bus stop
# 3    https://www.google.com/maps/place/Second+Gate+...  Bus stop
# 4    https://www.google.com/maps/place/Pero+Bus+Sto...  Bus stop
# ..                                                 ...       ...
# ...

# %%
dataa = data['placeUrl']

# %%
dataa
# Out:
# 0      https://www.google.com/maps/place/Garage+Bus+S...
# 1      https://www.google.com/maps/place/Stadium+Bus+...
# 2      https://www.google.com/maps/place/Agunbiade+Bu...
# 3      https://www.google.com/maps/place/Second+Gate+...
# 4      https://www.google.com/maps/place/Pero+Bus+Sto...
#                              ...
# 109    https://www.google.com/maps/place/Ikeja+%28Gen...
# 110    https://www.google.com/maps/place/LS+Bus+Stop/...
# 111    https://www.google.com/maps/place/Balogun+Bus+...
# 112    https://www.google.com/maps/place/Grand+Manor+...
# 113    https://www.google.com/maps/place/Shobowale+st...
# Name: placeUrl, Length: 114, dtype: object

# %%
def get_distance_by_road(origin, destination, api_key):
    # Construct the API request URL
    base_url = "https://maps.googleapis.com/maps/api/distancematrix/json"
    params = {
        'origins': origin,
        'destinations': destination,
        'mode': 'driving',  # Use 'driving' for driving distance
        'key': api_key
    }
    response = requests.get(base_url, params=params)
    data = response.json()

    print("API Response:", data)  # Print the API response to inspect its structure

    try:
        # Extract the distance in meters (you can convert to miles or km as needed)
        distance_meters = data['rows'][0]['elements'][0]['distance']['value']
        return distance_meters / 1000.0  # Convert to kilometers
    except IndexError:
        print("IndexError: List index out of range. Data structure may be unexpected.")
        return None

    # Extract the distance in meters (you can convert to miles or km as needed)
    distance_meters = data['rows'][0]['elements'][0]['distance']['value']
    return distance_meters # Convert to kilometers

if __name__ == "__main__":
    # City name or address
    city_address = "Yaba"  # Replace with the actual city name or address

    # Iterate through the DataFrame and get distances by road
    distances = []
    for url in data['placeUrl']:
        # Geocode the URL (you might need a separate geocoding API)
        # For simplicity, we'll use the URL itself as the origin
        origin = url

        # Geocode the city (you might need a geocoding API)
        destination = city_address

        # Replace 'YOUR_API_KEY' with your actual Google Maps API key
        api_key = 'AIzaSyCDGbobBigk4zgjSJHxfxf46uLDotzrDak'

        # Get the distance by road
        yaba = get_distance_by_road(origin, destination, api_key)
        distances.append(yaba)

    data['Yaba'] = distances

    data
# Out:
# API Response: {'destination_addresses': [], 'error_message': 'The provided API key is invalid. ', 'origin_addresses': [], 'rows': [], 'status': 'REQUEST_DENIED'}
# IndexError: List index out of range. Data structure may be unexpected.
# API Response: {'destination_addresses': [], 'error_message': 'The provided API key is invalid. ', 'origin_addresses': [], 'rows': [], 'status': 'REQUEST_DENIED'}
# IndexError: List index out of range. Data structure may be unexpected.
# API Response: {'destination_addresses': [], 'error_message': 'The provided API key is invalid. ', 'origin_addresses': [], 'rows': [], 'status': 'REQUEST_DENIED'}
# IndexError: List index out of range. Data structure may be unexpected.
# API Response: {'destination_addresses': [], 'error_message': 'The provided API key is invalid. ', 'origin_addresses': [], 'rows': [], 'status': 'REQUEST_DENIED'}
# IndexError: List index out of range. Data structure may be unexpected.
# ...

# %%
import googlemaps
gmaps = googlemaps.Client(key='AIzaSyCKCR9DgGyfMYqGZ3vhvyScvPxv04Iam28')
result = gmaps.distance_matrix('Surulere 101241, Lagos, Nigeria', 'Ikeja', mode='driving')
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# C:\Users\THEECC~1\AppData\Local\Temp/ipykernel_2192/1033905876.py in <module>
#       1 import googlemaps
#       2 gmaps = googlemaps.Client(key='AIzaSyCKCR9DgGyfMYqGZ3vhvyScvPxv04Iam28')
# ----> 3 result = gmaps.distance_matrix('Surulere 101241, Lagos, Nigeria', 'Ikeja', mode='driving')
#
# ~\anaconda3\lib\site-packages\googlemaps\client.py in wrapper(*args, **kwargs)
#     443     def wrapper(*args, **kwargs):
#     444         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 445         result = func(*args, **kwargs)
#     446         try:
#     447             del args[0]._extra_params
#
# ...

# %%
# !pip install -U googlemaps
